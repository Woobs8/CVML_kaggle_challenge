# %% [markdown]
# # VGG19 Training

# %%
from Models.VGG19.train_layers import train_classifier as vgg19_train
# boolean parameters
summary_only = False
use_resize = True
restart_training = False

# Datasets to use
train_img_path = "Data/Train/AugTrainImages" #TrainAugImages/"
train_labels_path = "Data/Train/trainAugLbls.npy" #augTrainLbls.txt"

val_img_path = "Data/Validation/ValidationImages/"
val_label_path = "Data/Validation/valLbls.txt"

# Start and Stop layers to train between and inclusive
start_layer = "clf_softmax"
stop_layer = "clf_softmax"

# folder to store params
folder_name_to_store_params = "/workspace/workspace/aug_clf_001"

# Folder where input model is loaded
input_model_path = None # default None

# Batch size to use
training_batch_size = 128

# Max number of Epochs to run 
max_number_of_epochs = 20

# Initial Learning Rate
initial_learning_rate = 0.001

# Classifier Dropout
clf_dropout = 0.5 # 0.5

# Parameters for early stopping
early_stop_patience = 3 # default 3
early_stop_min_increase = 0.002 # default 0.01

# Paramters for lr scheduler
learn_rate_drop = None 
epochs_between_lr_drop = None 
lr_sched = None # [learn_rate_drop,epochs_between_lr_drop] # default None


# Train Classifier
#if lr_sched == None :
#    !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}
#else:
#    !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -lr_sched {learn_rate_drop} {epochs_between_lr_drop} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}

# Train Train Block 1

start_layer = "clf_softmax"
stop_layer = "block1_conv1"

input_model_path = "/workspace/workspace/aug_clf_001/checkpoint.h5" # default None
initial_learning_rate = 0.0001
folder_name_to_store_params = "/workspace/workspace/aug_clf_001/b1c1_0001" # folder to store params
if lr_sched == None :
    # !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}
else:
    # !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -lr_sched {learn_rate_drop} {epochs_between_lr_drop} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}

input_model_path = folder_name_to_store_params + "/checkpoint.h5"# default None
initial_learning_rate = 0.00001
folder_name_to_store_params = folder_name_to_store_params + "/fine_00001" # folder to store params
if lr_sched == None :
    # !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}
else:
    # !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -lr_sched {learn_rate_drop} {epochs_between_lr_drop} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}

input_model_path = folder_name_to_store_params + "/checkpoint.h5" # default None
initial_learning_rate = 0.000001
folder_name_to_store_params = folder_name_to_store_params+"/fine_000001" # folder to store params
if lr_sched == None :
    # !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}
else:
    # !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -lr_sched {learn_rate_drop} {epochs_between_lr_drop} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -summary_only {summary_only} -restart {restart_training}


# Stop Instance

import socket
gce_name = socket.gethostname()
VMNAME= gce_name
ZONE="us-central1-c"

# !gcloud compute instances stop {VMNAME} --zone {ZONE} --quiet
# Out:
# /jet/var/python/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /jet/var/python/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Using existing model: /workspace/workspace/aug_clf_001/checkpoint.h5
# 2018-04-22 15:21:30.424897: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# ...

# %% [markdown]
# ## Data Whitening

# %%
from DataAugmentation import zca_whitening
from ImageReader import image_reader, create_image_lists
from scipy.misc import imsave
import os
def run_():
    # Get Image List
    img_list = create_image_lists("../Data/Train/TrainImages")
    img_name_list = [os.path.split(x)[1][:-4] for x in img_list]

    # load image data
    X_train, y_train = image_reader("../Data/Train/TrainImages","../Data/Train/trainLbls.txt")

    X_white = zca_whitening(X_train,zero_centered=False)
    
    # Save the images
    for idx, image in enumerate(X_train):
        im_path = os.path.join("../../CVML_augdata/ZcaAugTrainImages",'Image'+str(idx+1)+'.jpg')
        imsave(im_path, image)  
run_()

# %%
#@title Predict Test Set

input_model_folder_drive = "/workspace/workspace/aug_clf_001/b1c1_0001"

input_str = input_model_folder_drive+"/checkpoint.h5"


output_path_drive = "/workspace/workspace/preds_b1c1_001_instance_highest.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -output {output_path_drive} -input_model {input_str} -instance -decision_mode highest
output_path_drive = "/workspace/workspace/preds_b1c1_001_instance_avg.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -output {output_path_drive} -input_model {input_str} -instance
output_path_drive = "/workspace/workspace/preds_b1c1_001_img.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -output {output_path_drive} -input_model {input_str}
# Out:
# /jet/var/python/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Running non-augmented instance-based predictions
# 2018-04-24 08:51:58.224925: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-04-24 08:51:59.136012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:895] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-04-24 08:51:59.136316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1105] Found device 0 with properties:
# ...

# %%
test=1

# %%
# %reset -f

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4e1243bd22c6> in <module>()
# ----> 1 test
#
# NameError: name 'test' is not defined
