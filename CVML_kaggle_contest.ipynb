# %% [markdown]
# # VGG19 Training

# %%
from Models.VGG19.train_layers import train_classifier as vgg19_train
# boolean parameters
summary_only = False
use_resize = True
restart_training = False

# Datasets to use

train_img_path = "/workspace/workspace/CVML_augdata/ZcaAugTrainImages" #"Data/Train/AugTrainImages"  # "Data/Train/TrainImages"
train_labels_path = "/workspace/workspace/CVML_augdata/ZcaAugTrainLbls.npy" #"Data/Train/trainLbls.txt" #"Data/Train/trainAugLbls.npy"
val_img_path = "/workspace/workspace/CVML_augdata/ZcaValImages" #"Data/Validation/ValidationImages/"
val_label_path = "Data/Validation/valLbls.txt"

# Start and Stop layers to train between and inclusive
start_layer = "clf_softmax"
stop_layer = "clf_softmax"

# Tensorboard Path
tb_path = "/workspace/workspace/zca_aug_clf_001/logdir/clf_001"

# folder to store params
folder_name_to_store_params = "/workspace/workspace/zca_aug_clf_001"

# Folder where input model is loaded
input_model_path = None

# Batch size to use
training_batch_size = 128

# Max number of Epochs to run 
max_number_of_epochs = 20

# Initial Learning Rate
initial_learning_rate = 0.001

# Classifier Dropout
clf_dropout = 0.5 # 0.5

# Parameters for early stopping
early_stop_patience = 3 # default 3
early_stop_min_increase = 0.005 # default 0.01

# Paramters for lr plateau
lr_plateau_patience = 3
lr_plateau_min_delta = 0.1 
lr_plateau_factor = 0.1 
lr_plateau_min = initial_learning_rate

# Get Histogram Graphs
get_histograms = True

"""
# Train Classifier
"""

# !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -tb_path {tb_path} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -lr_plateau {lr_plateau_patience} {lr_plateau_min_delta} {lr_plateau_factor} {lr_plateau_min} -summary_only {summary_only} -restart {restart_training} -histogram_graphs get_histograms

"""
# Train Train Block 1
"""
early_stop_patience = 6 # default 3
early_stop_min_increase = 0.002 # default 0.01
lr_plateau_patience = 3
lr_plateau_min_delta = 0.05 
lr_plateau_factor = 0.1 
lr_drops = 2
initial_learning_rate = 0.0001
lr_plateau_min = initial_learning_rate * lr_plateau_factor**lr_drops
get_histograms = False

start_layer = "clf_softmax"
stop_layer = "block2_conv1"
tb_path = "/workspace/workspace/zca_aug_clf_001/logdir/b2c1"
input_model_path = "/workspace/workspace/zca_aug_clf_001/checkpoint.h5" # default None
folder_name_to_store_params = "/workspace/workspace/zca_aug_clf_001/b2c1" # folder to store params
# !python3 Models/VGG19/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -stop_layer {stop_layer} -start_layer {start_layer} -tb_path {tb_path} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -input_model {input_model_path} -lr_plateau {lr_plateau_patience} {lr_plateau_min_delta} {lr_plateau_factor} {lr_plateau_min} -summary_only {summary_only} -restart {restart_training} -histogram_graphs get_histograms


"""
# Stop Cloud Instance
"""

import socket
gce_name = socket.gethostname()
VMNAME= gce_name
ZONE="us-central1-c"

# !gcloud compute instances stop {VMNAME} --zone {ZONE} --quiet

# %% [markdown]
# # InceptionResNetV2Training

# %%
# boolean parameters
summary_only = False
use_resize = True
restart_training = False

workspace = "/workspace/workspace"
save_dir = workspace + "/inception_inst_based"

# Datasets to use
train_img_path = workspace + "/CVML_kaggle_challenge/Data/Train/TrainImages" 
train_labels_path = workspace + "/CVML_kaggle_challenge/Data/Train/trainLbls.txt"
val_img_path = workspace + "/CVML_kaggle_challenge/Data/Validation/ValidationImages/"
val_label_path = workspace + "/CVML_kaggle_challenge/Data/Validation/valLbls.txt"

# Start and Stop layers to train between and inclusive
train_mode = "prediction"

# Tensorboard Path
tb_path = save_dir + "/logdir/clf_001"

# folder to store params
folder_name_to_store_params = save_dir

# Folder where input model is loaded
input_model_path = None

# Batch size to use
training_batch_size = 256

# Max number of Epochs to run 
max_number_of_epochs = 3

# Instance based training
instance_based = True

# %cd /workspace/workspace/CVML_kaggle_challenge/

"""
# Train Classifier
"""
# Initial Learning Rate
initial_learning_rate = 0.001

# Classifier Dropout
clf_dropout = 0.2 # 0.5

# Parameters for early stopping
early_stop_patience = 3 # default 3
early_stop_min_increase = 0.01 # default 0.01

# Paramters for lr plateau
lr_plateau_patience = 3
lr_plateau_min_delta = 0.1 
lr_plateau_factor = 0.1 
lr_plateau_min = initial_learning_rate

# Get Histogram Graphs
get_histograms = False

# !python3 Models/InceptionResNetV2/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -train_mode {train_mode} -tb_path {tb_path} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -lr_plateau {lr_plateau_patience} {lr_plateau_min_delta} {lr_plateau_factor} {lr_plateau_min} -summary_only {summary_only} -restart {restart_training} -histogram_graphs {get_histograms} -inst_based {instance_based}


"""
# Train Module All
"""
max_number_of_epochs = 500
training_batch_size = 32
# Parameters for early stopping
early_stop_patience = 35 #default 3
early_stop_min_increase = 0.005 # default 0.01
lr_plateau_patience = 20
lr_plateau_min_delta = 0.01 
lr_plateau_factor = 0.1 
lr_drops = 2
initial_learning_rate = 0.0001
lr_plateau_min = initial_learning_rate * lr_plateau_factor**lr_drops
get_histograms = False


train_mode = "full"
tb_path = save_dir + "/logdir/full"
input_model_path = save_dir + "/checkpoint.h5" # default None
folder_name_to_store_params = save_dir + "/full" #+ "/all_dropout" # folder to store params
# !python3 Models/InceptionResNetV2/train_layers.py {train_img_path} {train_labels_path} {val_img_path} {val_label_path} -output {folder_name_to_store_params} -train_mode {train_mode} -tb_path {tb_path} -epochs {max_number_of_epochs} -lr {initial_learning_rate} -dropout {clf_dropout} -batch_size {training_batch_size} -early_stop {early_stop_patience} {early_stop_min_increase} -lr_plateau {lr_plateau_patience} {lr_plateau_min_delta} {lr_plateau_factor} {lr_plateau_min} -summary_only {summary_only} -use_resize {use_resize} -restart {restart_training} -histogram_graphs {get_histograms} -inst_based {instance_based} -input_model {input_model_path}


"""
# Stop Cloud Instance
"""

import socket
gce_name = socket.gethostname()
VMNAME= gce_name
ZONE="us-central1-c"

#!gcloud compute instances stop {VMNAME} --zone {ZONE} --quiet
# Out:
# /jet/prs/workspace/CVML_kaggle_challenge
# /jet/var/python/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 2018-05-01 14:33:43.952525: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-05-01 14:33:43.961588: E tensorflow/stream_executor/cuda/cuda_driver.cc:406] failed call to cuInit: CUDA_ERROR_UNKNOWN
# 2018-05-01 14:33:43.961642: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:145] kernel driver does not appear to be running on this host (rasmus-p100-keras-tf): /proc/driver/nvidia/version does not exist
# Models/InceptionResNetV2/train_layers.py:64: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("im..., outputs=Tensor("pr...)`
#   final_model = Model(input = inp, output = predictions)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_input_1_2 (InputLayer)    (None, None, None, 3 0
# __________________________________________________________________________________________________
# image_slice_1 (Lambda)          (None, None, None, 3 0           image_input_1_2[0][0]
# __________________________________________________________________________________________________
# image_slice_2 (Lambda)          (None, None, None, 3 0           image_input_1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1_1 (Conv2D)             (None, None, None, 3 864         image_slice_1[0][0]
# __________________________________________________________________________________________________
# conv2d_204_2 (Conv2D)           (None, None, None, 3 864         image_slice_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1_1 (BatchN (None, None, None, 3 96          conv2d_1_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204_2 (Batc (None, None, None, 3 96          conv2d_204_2[0][0]
# __________________________________________________________________________________________________
# activation_1_1 (Activation)     (None, None, None, 3 0           batch_normalization_1_1[0][0]
# __________________________________________________________________________________________________
# activation_204_2 (Activation)   (None, None, None, 3 0           batch_normalization_204_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2_1 (Conv2D)             (None, None, None, 3 9216        activation_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_205_2 (Conv2D)           (None, None, None, 3 9216        activation_204_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2_1 (BatchN (None, None, None, 3 96          conv2d_2_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205_2 (Batc (None, None, None, 3 96          conv2d_205_2[0][0]
# __________________________________________________________________________________________________
# activation_2_1 (Activation)     (None, None, None, 3 0           batch_normalization_2_1[0][0]
# __________________________________________________________________________________________________
# activation_205_2 (Activation)   (None, None, None, 3 0           batch_normalization_205_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3_1 (Conv2D)             (None, None, None, 6 18432       activation_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_206_2 (Conv2D)           (None, None, None, 6 18432       activation_205_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3_1 (BatchN (None, None, None, 6 192         conv2d_3_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206_2 (Batc (None, None, None, 6 192         conv2d_206_2[0][0]
# __________________________________________________________________________________________________
# activation_3_1 (Activation)     (None, None, None, 6 0           batch_normalization_3_1[0][0]
# __________________________________________________________________________________________________
# activation_206_2 (Activation)   (None, None, None, 6 0           batch_normalization_206_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1_1 (MaxPooling2D (None, None, None, 6 0           activation_3_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5_2 (MaxPooling2D (None, None, None, 6 0           activation_206_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4_1 (Conv2D)             (None, None, None, 8 5120        max_pooling2d_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_207_2 (Conv2D)           (None, None, None, 8 5120        max_pooling2d_5_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4_1 (BatchN (None, None, None, 8 240         conv2d_4_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207_2 (Batc (None, None, None, 8 240         conv2d_207_2[0][0]
# __________________________________________________________________________________________________
# activation_4_1 (Activation)     (None, None, None, 8 0           batch_normalization_4_1[0][0]
# __________________________________________________________________________________________________
# activation_207_2 (Activation)   (None, None, None, 8 0           batch_normalization_207_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5_1 (Conv2D)             (None, None, None, 1 138240      activation_4_1[0][0]
# __________________________________________________________________________________________________
# conv2d_208_2 (Conv2D)           (None, None, None, 1 138240      activation_207_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5_1 (BatchN (None, None, None, 1 576         conv2d_5_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208_2 (Batc (None, None, None, 1 576         conv2d_208_2[0][0]
# __________________________________________________________________________________________________
# activation_5_1 (Activation)     (None, None, None, 1 0           batch_normalization_5_1[0][0]
# __________________________________________________________________________________________________
# activation_208_2 (Activation)   (None, None, None, 1 0           batch_normalization_208_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2_1 (MaxPooling2D (None, None, None, 1 0           activation_5_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6_2 (MaxPooling2D (None, None, None, 1 0           activation_208_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9_1 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_212_2 (Conv2D)           (None, None, None, 6 12288       max_pooling2d_6_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9_1 (BatchN (None, None, None, 6 192         conv2d_9_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212_2 (Batc (None, None, None, 6 192         conv2d_212_2[0][0]
# __________________________________________________________________________________________________
# activation_9_1 (Activation)     (None, None, None, 6 0           batch_normalization_9_1[0][0]
# __________________________________________________________________________________________________
# activation_212_2 (Activation)   (None, None, None, 6 0           batch_normalization_212_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7_1 (Conv2D)             (None, None, None, 4 9216        max_pooling2d_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10_1 (Conv2D)            (None, None, None, 9 55296       activation_9_1[0][0]
# __________________________________________________________________________________________________
# conv2d_210_2 (Conv2D)           (None, None, None, 4 9216        max_pooling2d_6_2[0][0]
# __________________________________________________________________________________________________
# conv2d_213_2 (Conv2D)           (None, None, None, 9 55296       activation_212_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7_1 (BatchN (None, None, None, 4 144         conv2d_7_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10_1 (Batch (None, None, None, 9 288         conv2d_10_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210_2 (Batc (None, None, None, 4 144         conv2d_210_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213_2 (Batc (None, None, None, 9 288         conv2d_213_2[0][0]
# __________________________________________________________________________________________________
# activation_7_1 (Activation)     (None, None, None, 4 0           batch_normalization_7_1[0][0]
# __________________________________________________________________________________________________
# activation_10_1 (Activation)    (None, None, None, 9 0           batch_normalization_10_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1_1 (AverageP (None, None, None, 1 0           max_pooling2d_2_1[0][0]
# __________________________________________________________________________________________________
# activation_210_2 (Activation)   (None, None, None, 4 0           batch_normalization_210_2[0][0]
# __________________________________________________________________________________________________
# activation_213_2 (Activation)   (None, None, None, 9 0           batch_normalization_213_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2_2 (AverageP (None, None, None, 1 0           max_pooling2d_6_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6_1 (Conv2D)             (None, None, None, 9 18432       max_pooling2d_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8_1 (Conv2D)             (None, None, None, 6 76800       activation_7_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11_1 (Conv2D)            (None, None, None, 9 82944       activation_10_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12_1 (Conv2D)            (None, None, None, 6 12288       average_pooling2d_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_209_2 (Conv2D)           (None, None, None, 9 18432       max_pooling2d_6_2[0][0]
# __________________________________________________________________________________________________
# conv2d_211_2 (Conv2D)           (None, None, None, 6 76800       activation_210_2[0][0]
# __________________________________________________________________________________________________
# conv2d_214_2 (Conv2D)           (None, None, None, 9 82944       activation_213_2[0][0]
# __________________________________________________________________________________________________
# conv2d_215_2 (Conv2D)           (None, None, None, 6 12288       average_pooling2d_2_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6_1 (BatchN (None, None, None, 9 288         conv2d_6_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8_1 (BatchN (None, None, None, 6 192         conv2d_8_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11_1 (Batch (None, None, None, 9 288         conv2d_11_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12_1 (Batch (None, None, None, 6 192         conv2d_12_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209_2 (Batc (None, None, None, 9 288         conv2d_209_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211_2 (Batc (None, None, None, 6 192         conv2d_211_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214_2 (Batc (None, None, None, 9 288         conv2d_214_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215_2 (Batc (None, None, None, 6 192         conv2d_215_2[0][0]
# __________________________________________________________________________________________________
# activation_6_1 (Activation)     (None, None, None, 9 0           batch_normalization_6_1[0][0]
# __________________________________________________________________________________________________
# activation_8_1 (Activation)     (None, None, None, 6 0           batch_normalization_8_1[0][0]
# __________________________________________________________________________________________________
# activation_11_1 (Activation)    (None, None, None, 9 0           batch_normalization_11_1[0][0]
# __________________________________________________________________________________________________
# activation_12_1 (Activation)    (None, None, None, 6 0           batch_normalization_12_1[0][0]
# __________________________________________________________________________________________________
# activation_209_2 (Activation)   (None, None, None, 9 0           batch_normalization_209_2[0][0]
# __________________________________________________________________________________________________
# activation_211_2 (Activation)   (None, None, None, 6 0           batch_normalization_211_2[0][0]
# __________________________________________________________________________________________________
# activation_214_2 (Activation)   (None, None, None, 9 0           batch_normalization_214_2[0][0]
# __________________________________________________________________________________________________
# activation_215_2 (Activation)   (None, None, None, 6 0           batch_normalization_215_2[0][0]
# __________________________________________________________________________________________________
# mixed_5b_1 (Concatenate)        (None, None, None, 3 0           activation_6_1[0][0]
#                                                                  activation_8_1[0][0]
#                                                                  activation_11_1[0][0]
#                                                                  activation_12_1[0][0]
# __________________________________________________________________________________________________
# mixed_5b_2 (Concatenate)        (None, None, None, 3 0           activation_209_2[0][0]
#                                                                  activation_211_2[0][0]
#                                                                  activation_214_2[0][0]
#                                                                  activation_215_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16_1 (Conv2D)            (None, None, None, 3 10240       mixed_5b_1[0][0]
# __________________________________________________________________________________________________
# conv2d_219_2 (Conv2D)           (None, None, None, 3 10240       mixed_5b_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16_1 (Batch (None, None, None, 3 96          conv2d_16_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219_2 (Batc (None, None, None, 3 96          conv2d_219_2[0][0]
# __________________________________________________________________________________________________
# activation_16_1 (Activation)    (None, None, None, 3 0           batch_normalization_16_1[0][0]
# __________________________________________________________________________________________________
# activation_219_2 (Activation)   (None, None, None, 3 0           batch_normalization_219_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14_1 (Conv2D)            (None, None, None, 3 10240       mixed_5b_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17_1 (Conv2D)            (None, None, None, 4 13824       activation_16_1[0][0]
# __________________________________________________________________________________________________
# conv2d_217_2 (Conv2D)           (None, None, None, 3 10240       mixed_5b_2[0][0]
# __________________________________________________________________________________________________
# conv2d_220_2 (Conv2D)           (None, None, None, 4 13824       activation_219_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14_1 (Batch (None, None, None, 3 96          conv2d_14_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17_1 (Batch (None, None, None, 4 144         conv2d_17_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217_2 (Batc (None, None, None, 3 96          conv2d_217_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220_2 (Batc (None, None, None, 4 144         conv2d_220_2[0][0]
# __________________________________________________________________________________________________
# activation_14_1 (Activation)    (None, None, None, 3 0           batch_normalization_14_1[0][0]
# __________________________________________________________________________________________________
# activation_17_1 (Activation)    (None, None, None, 4 0           batch_normalization_17_1[0][0]
# __________________________________________________________________________________________________
# activation_217_2 (Activation)   (None, None, None, 3 0           batch_normalization_217_2[0][0]
# __________________________________________________________________________________________________
# activation_220_2 (Activation)   (None, None, None, 4 0           batch_normalization_220_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13_1 (Conv2D)            (None, None, None, 3 10240       mixed_5b_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15_1 (Conv2D)            (None, None, None, 3 9216        activation_14_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18_1 (Conv2D)            (None, None, None, 6 27648       activation_17_1[0][0]
# __________________________________________________________________________________________________
# conv2d_216_2 (Conv2D)           (None, None, None, 3 10240       mixed_5b_2[0][0]
# __________________________________________________________________________________________________
# conv2d_218_2 (Conv2D)           (None, None, None, 3 9216        activation_217_2[0][0]
# __________________________________________________________________________________________________
# conv2d_221_2 (Conv2D)           (None, None, None, 6 27648       activation_220_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13_1 (Batch (None, None, None, 3 96          conv2d_13_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15_1 (Batch (None, None, None, 3 96          conv2d_15_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18_1 (Batch (None, None, None, 6 192         conv2d_18_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216_2 (Batc (None, None, None, 3 96          conv2d_216_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218_2 (Batc (None, None, None, 3 96          conv2d_218_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221_2 (Batc (None, None, None, 6 192         conv2d_221_2[0][0]
# __________________________________________________________________________________________________
# activation_13_1 (Activation)    (None, None, None, 3 0           batch_normalization_13_1[0][0]
# __________________________________________________________________________________________________
# activation_15_1 (Activation)    (None, None, None, 3 0           batch_normalization_15_1[0][0]
# __________________________________________________________________________________________________
# activation_18_1 (Activation)    (None, None, None, 6 0           batch_normalization_18_1[0][0]
# __________________________________________________________________________________________________
# activation_216_2 (Activation)   (None, None, None, 3 0           batch_normalization_216_2[0][0]
# __________________________________________________________________________________________________
# activation_218_2 (Activation)   (None, None, None, 3 0           batch_normalization_218_2[0][0]
# __________________________________________________________________________________________________
# activation_221_2 (Activation)   (None, None, None, 6 0           batch_normalization_221_2[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed_1 (Concatenate) (None, None, None, 1 0           activation_13_1[0][0]
#                                                                  activation_15_1[0][0]
#                                                                  activation_18_1[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed_2 (Concatenate) (None, None, None, 1 0           activation_216_2[0][0]
#                                                                  activation_218_2[0][0]
#                                                                  activation_221_2[0][0]
# __________________________________________________________________________________________________
# block35_1_conv_1 (Conv2D)       (None, None, None, 3 41280       block35_1_mixed_1[0][0]
# __________________________________________________________________________________________________
# block35_1_conv_2 (Conv2D)       (None, None, None, 3 41280       block35_1_mixed_2[0][0]
# __________________________________________________________________________________________________
# block35_1_1 (Lambda)            (None, None, None, 3 0           mixed_5b_1[0][0]
#                                                                  block35_1_conv_1[0][0]
# __________________________________________________________________________________________________
# block35_1_2 (Lambda)            (None, None, None, 3 0           mixed_5b_2[0][0]
#                                                                  block35_1_conv_2[0][0]
# __________________________________________________________________________________________________
# block35_1_ac_1 (Activation)     (None, None, None, 3 0           block35_1_1[0][0]
# __________________________________________________________________________________________________
# block35_1_ac_2 (Activation)     (None, None, None, 3 0           block35_1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22_1 (Conv2D)            (None, None, None, 3 10240       block35_1_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_225_2 (Conv2D)           (None, None, None, 3 10240       block35_1_ac_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22_1 (Batch (None, None, None, 3 96          conv2d_22_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225_2 (Batc (None, None, None, 3 96          conv2d_225_2[0][0]
# __________________________________________________________________________________________________
# activation_22_1 (Activation)    (None, None, None, 3 0           batch_normalization_22_1[0][0]
# __________________________________________________________________________________________________
# activation_225_2 (Activation)   (None, None, None, 3 0           batch_normalization_225_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20_1 (Conv2D)            (None, None, None, 3 10240       block35_1_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_23_1 (Conv2D)            (None, None, None, 4 13824       activation_22_1[0][0]
# __________________________________________________________________________________________________
# conv2d_223_2 (Conv2D)           (None, None, None, 3 10240       block35_1_ac_2[0][0]
# __________________________________________________________________________________________________
# conv2d_226_2 (Conv2D)           (None, None, None, 4 13824       activation_225_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20_1 (Batch (None, None, None, 3 96          conv2d_20_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23_1 (Batch (None, None, None, 4 144         conv2d_23_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223_2 (Batc (None, None, None, 3 96          conv2d_223_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226_2 (Batc (None, None, None, 4 144         conv2d_226_2[0][0]
# __________________________________________________________________________________________________
# activation_20_1 (Activation)    (None, None, None, 3 0           batch_normalization_20_1[0][0]
# __________________________________________________________________________________________________
# activation_23_1 (Activation)    (None, None, None, 4 0           batch_normalization_23_1[0][0]
# __________________________________________________________________________________________________
# activation_223_2 (Activation)   (None, None, None, 3 0           batch_normalization_223_2[0][0]
# __________________________________________________________________________________________________
# activation_226_2 (Activation)   (None, None, None, 4 0           batch_normalization_226_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19_1 (Conv2D)            (None, None, None, 3 10240       block35_1_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21_1 (Conv2D)            (None, None, None, 3 9216        activation_20_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24_1 (Conv2D)            (None, None, None, 6 27648       activation_23_1[0][0]
# __________________________________________________________________________________________________
# conv2d_222_2 (Conv2D)           (None, None, None, 3 10240       block35_1_ac_2[0][0]
# __________________________________________________________________________________________________
# conv2d_224_2 (Conv2D)           (None, None, None, 3 9216        activation_223_2[0][0]
# __________________________________________________________________________________________________
# conv2d_227_2 (Conv2D)           (None, None, None, 6 27648       activation_226_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19_1 (Batch (None, None, None, 3 96          conv2d_19_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21_1 (Batch (None, None, None, 3 96          conv2d_21_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24_1 (Batch (None, None, None, 6 192         conv2d_24_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222_2 (Batc (None, None, None, 3 96          conv2d_222_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224_2 (Batc (None, None, None, 3 96          conv2d_224_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227_2 (Batc (None, None, None, 6 192         conv2d_227_2[0][0]
# __________________________________________________________________________________________________
# activation_19_1 (Activation)    (None, None, None, 3 0           batch_normalization_19_1[0][0]
# __________________________________________________________________________________________________
# activation_21_1 (Activation)    (None, None, None, 3 0           batch_normalization_21_1[0][0]
# __________________________________________________________________________________________________
# activation_24_1 (Activation)    (None, None, None, 6 0           batch_normalization_24_1[0][0]
# __________________________________________________________________________________________________
# activation_222_2 (Activation)   (None, None, None, 3 0           batch_normalization_222_2[0][0]
# __________________________________________________________________________________________________
# activation_224_2 (Activation)   (None, None, None, 3 0           batch_normalization_224_2[0][0]
# __________________________________________________________________________________________________
# activation_227_2 (Activation)   (None, None, None, 6 0           batch_normalization_227_2[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed_1 (Concatenate) (None, None, None, 1 0           activation_19_1[0][0]
#                                                                  activation_21_1[0][0]
#                                                                  activation_24_1[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed_2 (Concatenate) (None, None, None, 1 0           activation_222_2[0][0]
#                                                                  activation_224_2[0][0]
#                                                                  activation_227_2[0][0]
# __________________________________________________________________________________________________
# block35_2_conv_1 (Conv2D)       (None, None, None, 3 41280       block35_2_mixed_1[0][0]
# __________________________________________________________________________________________________
# block35_2_conv_2 (Conv2D)       (None, None, None, 3 41280       block35_2_mixed_2[0][0]
# __________________________________________________________________________________________________
# block35_2_1 (Lambda)            (None, None, None, 3 0           block35_1_ac_1[0][0]
#                                                                  block35_2_conv_1[0][0]
# __________________________________________________________________________________________________
# block35_2_2 (Lambda)            (None, None, None, 3 0           block35_1_ac_2[0][0]
#                                                                  block35_2_conv_2[0][0]
# __________________________________________________________________________________________________
# block35_2_ac_1 (Activation)     (None, None, None, 3 0           block35_2_1[0][0]
# __________________________________________________________________________________________________
# block35_2_ac_2 (Activation)     (None, None, None, 3 0           block35_2_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28_1 (Conv2D)            (None, None, None, 3 10240       block35_2_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_231_2 (Conv2D)           (None, None, None, 3 10240       block35_2_ac_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28_1 (Batch (None, None, None, 3 96          conv2d_28_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231_2 (Batc (None, None, None, 3 96          conv2d_231_2[0][0]
# __________________________________________________________________________________________________
# activation_28_1 (Activation)    (None, None, None, 3 0           batch_normalization_28_1[0][0]
# __________________________________________________________________________________________________
# activation_231_2 (Activation)   (None, None, None, 3 0           batch_normalization_231_2[0][0]
# __________________________________________________________________________________________________
# conv2d_26_1 (Conv2D)            (None, None, None, 3 10240       block35_2_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_29_1 (Conv2D)            (None, None, None, 4 13824       activation_28_1[0][0]
# __________________________________________________________________________________________________
# conv2d_229_2 (Conv2D)           (None, None, None, 3 10240       block35_2_ac_2[0][0]
# __________________________________________________________________________________________________
# conv2d_232_2 (Conv2D)           (None, None, None, 4 13824       activation_231_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26_1 (Batch (None, None, None, 3 96          conv2d_26_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29_1 (Batch (None, None, None, 4 144         conv2d_29_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229_2 (Batc (None, None, None, 3 96          conv2d_229_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232_2 (Batc (None, None, None, 4 144         conv2d_232_2[0][0]
# __________________________________________________________________________________________________
# activation_26_1 (Activation)    (None, None, None, 3 0           batch_normalization_26_1[0][0]
# __________________________________________________________________________________________________
# activation_29_1 (Activation)    (None, None, None, 4 0           batch_normalization_29_1[0][0]
# __________________________________________________________________________________________________
# activation_229_2 (Activation)   (None, None, None, 3 0           batch_normalization_229_2[0][0]
# __________________________________________________________________________________________________
# activation_232_2 (Activation)   (None, None, None, 4 0           batch_normalization_232_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25_1 (Conv2D)            (None, None, None, 3 10240       block35_2_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_27_1 (Conv2D)            (None, None, None, 3 9216        activation_26_1[0][0]
# __________________________________________________________________________________________________
# conv2d_30_1 (Conv2D)            (None, None, None, 6 27648       activation_29_1[0][0]
# __________________________________________________________________________________________________
# conv2d_228_2 (Conv2D)           (None, None, None, 3 10240       block35_2_ac_2[0][0]
# __________________________________________________________________________________________________
# conv2d_230_2 (Conv2D)           (None, None, None, 3 9216        activation_229_2[0][0]
# __________________________________________________________________________________________________
# conv2d_233_2 (Conv2D)           (None, None, None, 6 27648       activation_232_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25_1 (Batch (None, None, None, 3 96          conv2d_25_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27_1 (Batch (None, None, None, 3 96          conv2d_27_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30_1 (Batch (None, None, None, 6 192         conv2d_30_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228_2 (Batc (None, None, None, 3 96          conv2d_228_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230_2 (Batc (None, None, None, 3 96          conv2d_230_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233_2 (Batc (None, None, None, 6 192         conv2d_233_2[0][0]
# __________________________________________________________________________________________________
# activation_25_1 (Activation)    (None, None, None, 3 0           batch_normalization_25_1[0][0]
# __________________________________________________________________________________________________
# activation_27_1 (Activation)    (None, None, None, 3 0           batch_normalization_27_1[0][0]
# __________________________________________________________________________________________________
# activation_30_1 (Activation)    (None, None, None, 6 0           batch_normalization_30_1[0][0]
# __________________________________________________________________________________________________
# activation_228_2 (Activation)   (None, None, None, 3 0           batch_normalization_228_2[0][0]
# __________________________________________________________________________________________________
# activation_230_2 (Activation)   (None, None, None, 3 0           batch_normalization_230_2[0][0]
# __________________________________________________________________________________________________
# activation_233_2 (Activation)   (None, None, None, 6 0           batch_normalization_233_2[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed_1 (Concatenate) (None, None, None, 1 0           activation_25_1[0][0]
#                                                                  activation_27_1[0][0]
#                                                                  activation_30_1[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed_2 (Concatenate) (None, None, None, 1 0           activation_228_2[0][0]
#                                                                  activation_230_2[0][0]
#                                                                  activation_233_2[0][0]
# __________________________________________________________________________________________________
# block35_3_conv_1 (Conv2D)       (None, None, None, 3 41280       block35_3_mixed_1[0][0]
# __________________________________________________________________________________________________
# block35_3_conv_2 (Conv2D)       (None, None, None, 3 41280       block35_3_mixed_2[0][0]
# __________________________________________________________________________________________________
# block35_3_1 (Lambda)            (None, None, None, 3 0           block35_2_ac_1[0][0]
#                                                                  block35_3_conv_1[0][0]
# __________________________________________________________________________________________________
# block35_3_2 (Lambda)            (None, None, None, 3 0           block35_2_ac_2[0][0]
#                                                                  block35_3_conv_2[0][0]
# __________________________________________________________________________________________________
# block35_3_ac_1 (Activation)     (None, None, None, 3 0           block35_3_1[0][0]
# __________________________________________________________________________________________________
# block35_3_ac_2 (Activation)     (None, None, None, 3 0           block35_3_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34_1 (Conv2D)            (None, None, None, 3 10240       block35_3_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_237_2 (Conv2D)           (None, None, None, 3 10240       block35_3_ac_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34_1 (Batch (None, None, None, 3 96          conv2d_34_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237_2 (Batc (None, None, None, 3 96          conv2d_237_2[0][0]
# __________________________________________________________________________________________________
# activation_34_1 (Activation)    (None, None, None, 3 0           batch_normalization_34_1[0][0]
# __________________________________________________________________________________________________
# activation_237_2 (Activation)   (None, None, None, 3 0           batch_normalization_237_2[0][0]
# __________________________________________________________________________________________________
# conv2d_32_1 (Conv2D)            (None, None, None, 3 10240       block35_3_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_35_1 (Conv2D)            (None, None, None, 4 13824       activation_34_1[0][0]
# __________________________________________________________________________________________________
# ...
# conv2d_401_2 (Conv2D)           (None, None, None, 2 129024      activation_400_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198_1 (Batc (None, None, None, 2 672         conv2d_198_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_401_2 (Batc (None, None, None, 2 672         conv2d_401_2[0][0]
# __________________________________________________________________________________________________
# activation_198_1 (Activation)   (None, None, None, 2 0           batch_normalization_198_1[0][0]
# __________________________________________________________________________________________________
# activation_401_2 (Activation)   (None, None, None, 2 0           batch_normalization_401_2[0][0]
# __________________________________________________________________________________________________
# conv2d_196_1 (Conv2D)           (None, None, None, 1 399360      block8_8_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_199_1 (Conv2D)           (None, None, None, 2 172032      activation_198_1[0][0]
# __________________________________________________________________________________________________
# conv2d_399_2 (Conv2D)           (None, None, None, 1 399360      block8_8_ac_2[0][0]
# __________________________________________________________________________________________________
# conv2d_402_2 (Conv2D)           (None, None, None, 2 172032      activation_401_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196_1 (Batc (None, None, None, 1 576         conv2d_196_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199_1 (Batc (None, None, None, 2 768         conv2d_199_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_399_2 (Batc (None, None, None, 1 576         conv2d_399_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_402_2 (Batc (None, None, None, 2 768         conv2d_402_2[0][0]
# __________________________________________________________________________________________________
# activation_196_1 (Activation)   (None, None, None, 1 0           batch_normalization_196_1[0][0]
# __________________________________________________________________________________________________
# activation_199_1 (Activation)   (None, None, None, 2 0           batch_normalization_199_1[0][0]
# __________________________________________________________________________________________________
# activation_399_2 (Activation)   (None, None, None, 1 0           batch_normalization_399_2[0][0]
# __________________________________________________________________________________________________
# activation_402_2 (Activation)   (None, None, None, 2 0           batch_normalization_402_2[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed_1 (Concatenate)  (None, None, None, 4 0           activation_196_1[0][0]
#                                                                  activation_199_1[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed_2 (Concatenate)  (None, None, None, 4 0           activation_399_2[0][0]
#                                                                  activation_402_2[0][0]
# __________________________________________________________________________________________________
# block8_9_conv_1 (Conv2D)        (None, None, None, 2 933920      block8_9_mixed_1[0][0]
# __________________________________________________________________________________________________
# block8_9_conv_2 (Conv2D)        (None, None, None, 2 933920      block8_9_mixed_2[0][0]
# __________________________________________________________________________________________________
# block8_9_1 (Lambda)             (None, None, None, 2 0           block8_8_ac_1[0][0]
#                                                                  block8_9_conv_1[0][0]
# __________________________________________________________________________________________________
# block8_9_2 (Lambda)             (None, None, None, 2 0           block8_8_ac_2[0][0]
#                                                                  block8_9_conv_2[0][0]
# __________________________________________________________________________________________________
# block8_9_ac_1 (Activation)      (None, None, None, 2 0           block8_9_1[0][0]
# __________________________________________________________________________________________________
# block8_9_ac_2 (Activation)      (None, None, None, 2 0           block8_9_2[0][0]
# __________________________________________________________________________________________________
# conv2d_201_1 (Conv2D)           (None, None, None, 1 399360      block8_9_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_404_2 (Conv2D)           (None, None, None, 1 399360      block8_9_ac_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201_1 (Batc (None, None, None, 1 576         conv2d_201_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_404_2 (Batc (None, None, None, 1 576         conv2d_404_2[0][0]
# __________________________________________________________________________________________________
# activation_201_1 (Activation)   (None, None, None, 1 0           batch_normalization_201_1[0][0]
# __________________________________________________________________________________________________
# activation_404_2 (Activation)   (None, None, None, 1 0           batch_normalization_404_2[0][0]
# __________________________________________________________________________________________________
# conv2d_202_1 (Conv2D)           (None, None, None, 2 129024      activation_201_1[0][0]
# __________________________________________________________________________________________________
# conv2d_405_2 (Conv2D)           (None, None, None, 2 129024      activation_404_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202_1 (Batc (None, None, None, 2 672         conv2d_202_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_405_2 (Batc (None, None, None, 2 672         conv2d_405_2[0][0]
# __________________________________________________________________________________________________
# activation_202_1 (Activation)   (None, None, None, 2 0           batch_normalization_202_1[0][0]
# __________________________________________________________________________________________________
# activation_405_2 (Activation)   (None, None, None, 2 0           batch_normalization_405_2[0][0]
# __________________________________________________________________________________________________
# conv2d_200_1 (Conv2D)           (None, None, None, 1 399360      block8_9_ac_1[0][0]
# __________________________________________________________________________________________________
# conv2d_203_1 (Conv2D)           (None, None, None, 2 172032      activation_202_1[0][0]
# __________________________________________________________________________________________________
# conv2d_403_2 (Conv2D)           (None, None, None, 1 399360      block8_9_ac_2[0][0]
# __________________________________________________________________________________________________
# conv2d_406_2 (Conv2D)           (None, None, None, 2 172032      activation_405_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200_1 (Batc (None, None, None, 1 576         conv2d_200_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203_1 (Batc (None, None, None, 2 768         conv2d_203_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_403_2 (Batc (None, None, None, 1 576         conv2d_403_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_406_2 (Batc (None, None, None, 2 768         conv2d_406_2[0][0]
# __________________________________________________________________________________________________
# activation_200_1 (Activation)   (None, None, None, 1 0           batch_normalization_200_1[0][0]
# __________________________________________________________________________________________________
# activation_203_1 (Activation)   (None, None, None, 2 0           batch_normalization_203_1[0][0]
# __________________________________________________________________________________________________
# activation_403_2 (Activation)   (None, None, None, 1 0           batch_normalization_403_2[0][0]
# __________________________________________________________________________________________________
# activation_406_2 (Activation)   (None, None, None, 2 0           batch_normalization_406_2[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed_1 (Concatenate) (None, None, None, 4 0           activation_200_1[0][0]
#                                                                  activation_203_1[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed_2 (Concatenate) (None, None, None, 4 0           activation_403_2[0][0]
#                                                                  activation_406_2[0][0]
# __________________________________________________________________________________________________
# block8_10_conv_1 (Conv2D)       (None, None, None, 2 933920      block8_10_mixed_1[0][0]
# __________________________________________________________________________________________________
# block8_10_conv_2 (Conv2D)       (None, None, None, 2 933920      block8_10_mixed_2[0][0]
# __________________________________________________________________________________________________
# block8_10_1 (Lambda)            (None, None, None, 2 0           block8_9_ac_1[0][0]
#                                                                  block8_10_conv_1[0][0]
# __________________________________________________________________________________________________
# block8_10_2 (Lambda)            (None, None, None, 2 0           block8_9_ac_2[0][0]
#                                                                  block8_10_conv_2[0][0]
# __________________________________________________________________________________________________
# conv_7b_1 (Conv2D)              (None, None, None, 1 3194880     block8_10_1[0][0]
# __________________________________________________________________________________________________
# conv_7b_2 (Conv2D)              (None, None, None, 1 3194880     block8_10_2[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn_1 (BatchNormalizatio (None, None, None, 1 4608        conv_7b_1[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn_2 (BatchNormalizatio (None, None, None, 1 4608        conv_7b_2[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac_1 (Activation)       (None, None, None, 1 0           conv_7b_bn_1[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac_2 (Activation)       (None, None, None, 1 0           conv_7b_bn_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1_1 (G (None, 1536)         0           conv_7b_ac_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2_2 (G (None, 1536)         0           conv_7b_ac_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1536)         0           global_average_pooling2d_1_1[0][0
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1536)         0           global_average_pooling2d_2_2[0][0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3072)         0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 29)           89117       concatenate_1[0][0]
# ==================================================================================================
# Total params: 108,762,589
# Trainable params: 108,641,501
# Non-trainable params: 121,088
# __________________________________________________________________________________________________
# Epoch 1/3
# terminate called after throwing an instance of 'std::bad_alloc'
#   what():  std::bad_alloc
# /jet/var/python/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Using existing model: /workspace/workspace/inception_inst_based/checkpoint.h5
# Traceback (most recent call last):
#   File "Models/InceptionResNetV2/train_layers.py", line 296, in <module>
#     instance_based=args.inst_based)
#   File "Models/InceptionResNetV2/train_layers.py", line 90, in train_classifier
#     final_model = load_model(input_model)
#   File "/jet/var/python/lib/python3.6/site-packages/keras/models.py", line 237, in load_model
#     with h5py.File(filepath, mode='r') as f:
#   File "/jet/var/python/lib/python3.6/site-packages/h5py/_hl/files.py", line 269, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#   File "/jet/var/python/lib/python3.6/site-packages/h5py/_hl/files.py", line 99, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 78, in h5py.h5f.open
# OSError: Unable to open file (unable to open file: name = '/workspace/workspace/inception_inst_based/checkpoint.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
#@title Predict Test Set

input_model_folder_drive = "/workspace/workspace/inception_adam_reg_no_pre"
input_str = input_model_folder_drive+"/checkpoint.h5"

aug5_data = "/workspace/workspace/CVML_augdata/AugTestImages"
aug10_data = "/workspace/workspace/CVML_augdata/AugTestImagesLarge"

# regular prediction
output_path_drive = input_model_folder_drive + "/inception_img_preds.txt"
#!python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -output {output_path_drive} -input_model {input_str}

# average instance prediction
output_path_drive = input_model_folder_drive + "/avg_inst_preds.txt"
#!python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -output {output_path_drive} -input_model {input_str} -instance

# high instance prediction
output_path_drive = input_model_folder_drive + "/high_inst_preds.txt"
#!python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -output {output_path_drive} -input_model {input_str} -instance

# highest aug5
output_path_drive = input_model_folder_drive + "/high_aug5_inst_preds.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -aug_test_data {aug5_data} -output {output_path_drive} -input_model {input_str} -instance -augmented -decision_mode highest

# average aug5
output_path_drive = input_model_folder_drive + "/avg_aug5_inst_preds.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -aug_test_data {aug5_data} -output {output_path_drive} -input_model {input_str} -instance -augmented

# weighted average aug5
output_path_drive = input_model_folder_drive + "/w_avg_aug5_inst_preds.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -aug_test_data {aug5_data} -output {output_path_drive} -input_model {input_str} -instance -augmented -decision_mode weighted_average

# highest aug10
output_path_drive = input_model_folder_drive + "/high_aug10_inst_preds.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -aug_test_data {aug10_data} -output {output_path_drive} -input_model {input_str} -instance -augmented -decision_mode highest

# average aug10
output_path_drive = input_model_folder_drive + "/avg_aug10_inst_preds.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -aug_test_data {aug10_data} -output {output_path_drive} -input_model {input_str} -instance -augmented

# weighted average aug10
output_path_drive = input_model_folder_drive + "/w_avg_aug10_inst_preds.txt"
# !python3 Models/VGG19/predict.py -test_data Data/Test/TestImages -aug_test_data {aug10_data} -output {output_path_drive} -input_model {input_str} -instance -augmented -decision_mode weighted_average

# %%
import socket
gce_name = socket.gethostname()
VMNAME= gce_name
ZONE="us-central1-c"

# !gcloud compute instances stop {VMNAME} --zone {ZONE} --quiet
