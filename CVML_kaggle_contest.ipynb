# %% [markdown]
# # VGG19 Training

# %%
from Models.VGG19.train_layers import train_classifier as vgg19_train
# boolean parameters
summary_only = False
use_resize = True
restart_training = False

# Datasets to use
train_img_path = "Data/Train/TrainImages" #TrainAugImages/"
train_labels_path = "Data/Train/trainLbls.txt" #augTrainLbls.txt"

val_img_path = "Data/Validation/ValidationImages/"
val_label_path = "Data/Validation/valLbls.txt"

# Start and Stop layers to train between and inclusive
start_layer = "clf_softmax"
stop_layer = "clf_softmax"

# folder to store params
folder_name_to_store_params = "/workspace/workspace/aug_clf_001"

# Folder where input model is loaded
input_model_path = None # default None

# Batch size to use
training_batch_size = 64 

# Max number of Epochs to run 
max_number_of_epochs = 20

# Initial Learning Rate
initial_learning_rate = 0.001

# Classifier Dropout
clf_dropout = 0.5 # 0.5

# Parameters for early stopping
early_stop_patience = 3 # default 3
early_stop_min_increase = 0.01 # default 0.01

# Paramters for lr scheduler
learn_rate_drop = None 
epochs_between_lr_drop = None 
lr_sched = None # [learn_rate_drop,epochs_between_lr_drop] # default None

vgg19_train(train_img_path, train_labels_path, val_img_path, val_label_path, folder_name_to_store_params, max_number_of_epochs, initial_learning_rate, training_batch_size, start_layer, stop_layer, [early_stop_patience, early_stop_min_increase], clf_dropout, lr_sched, input_model_path, summary_only, use_resize, restart_training)
# Out:
# INFO:tensorflow:Looking for images in 'TrainImages'
# INFO:tensorflow:Looking for images in ''
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# image_input (InputLayer)     (None, None, None, 3)     0
# _________________________________________________________________
# image_resize (Lambda)        (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# ...
